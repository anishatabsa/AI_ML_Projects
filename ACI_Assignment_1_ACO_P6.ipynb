# %% [markdown]
# # Artificial and Computational Intelligence Assignment 1

# %% [markdown]
# ## Problem solving by Informed Search and/or Local Search

# %% [markdown]
# **Mandatory Detail: The Word  document and IPYNB FILE must include:**
#
# o	BITS IDs of all team members
#
# o	Their individual contribution percentages
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Coding begins here

# %% [markdown]
# ### 1.	Define the environment in the following block

# %% [markdown]
# List the PEAS decription of the problem here in this markdown block

# %%
# PEAS Explanation
PEAS = {
    "Performance Measure": "Maximize total value of items packed without exceeding 20kg.",
    "Environment": "Backpack with 20kg capacity, 8 item types with given weights and values.",
    "Actuator": "Packing items into the backpack.",
    "Sensor": "Detecting item weights, values, and current bag weight."
}

print("PEAS for the agent:")
for k, v in PEAS.items():
    print(f"{k}: {v}")
print("\n")
# Out:
# PEAS for the agent:
# Performance Measure: Maximize total value of items packed without exceeding 20kg.
# Environment: Backpack with 20kg capacity, 8 item types with given weights and values.
# Actuator: Packing items into the backpack.
# Sensor: Detecting item weights, values, and current bag weight.

# %% [markdown]
# Design the agent as PSA Agent(Problem Solving Agent)
# Clear Initial data structures to define the graph and variable declarations is expected
# IMPORTATANT: Write distinct code block as below

# %%
#Code Block : Set Initial State (Must handle dynamic inputs)

import numpy as np
import matplotlib.pyplot as plt
import sys
import time

# %%
# Data
items = [
    {"name": "Tent", "weight": 5, "value": 2},
    {"name": "Sleeping Bag", "weight": 3, "value": 3},
    {"name": "Water Bottle", "weight": 4, "value": 1},
    {"name": "Fruits", "weight": 2, "value": 6},
    {"name": "Mosquito bite cream", "weight": 10, "value": 4},
    {"name": "Map & Compass", "weight": 5, "value": 5},
    {"name": "Umberalla", "weight": 6, "value": 8},
    {"name": "Flashlight", "weight": 1, "value": 7},
]
weights = np.array([item["weight"] for item in items])
values = np.array([item["value"] for item in items])
item_names = [item["name"] for item in items]
capacity = 20
num_items = len(weights)

print("Available items:")
for item in items:
    print(f"  {item['name']}: weight={item['weight']}kg, value={item['value']}")
print(f"\nBackpack capacity: {capacity} kg")
# Out:
# Available items:
#   Tent: weight=5kg, value=2
#   Sleeping Bag: weight=3kg, value=3
#   Water Bottle: weight=4kg, value=1
#   Fruits: weight=2kg, value=6
#   Mosquito bite cream: weight=10kg, value=4
#   Map & Compass: weight=5kg, value=5
#   Umberalla: weight=6kg, value=8
#   Flashlight: weight=1kg, value=7
#
# Backpack capacity: 20 kg

# %% [markdown]
# ### 2.	Definition of Algorithm  (ACO )

# %%
#Code Block : Set the matrix for transition & cost (as relevant for the given problem)

def cost_matrix(weights, values):
    # Value-to-weight ratio as "cost", but invert value so that 1 is highest importance
    inverted_values = 9 - values  # since values go from 1 (most important) to 8 (least)
    return inverted_values / weights

# %%
def transition_matrix(pheromone, cost, alpha, beta):
    # Calculate transition probabilities
    tau = pheromone ** alpha
    eta = cost ** beta
    prob = tau * eta
    prob = prob / np.sum(prob)
    return prob

# %%
def pheromone_update(pheromone, all_solutions, all_values, evaporation=0.1):
    # Evaporate
    pheromone *= (1 - evaporation)
    # Reinforce
    for solution, value in zip(all_solutions, all_values):
        for idx in solution:
            pheromone[idx] += value / 100.0  # scale reinforcement
            
    # Print pheromone levels for each item after update
    print("\nPheromone levels after update (per item):")
    for idx, level in enumerate(pheromone):
        print(f"  Item {item_names[idx]}: {level:.4f}")

    return pheromone

# %%
def aco_algorithm(weights, values, capacity, num_ants, alpha, beta, num_iter=100):
    pheromone = np.ones(num_items)
    cost = cost_matrix(weights, values)
    best_value = 0
    best_solution = []
    convergence = []
    pheromone_history = []

    for it in range(num_iter):
        all_solutions = []
        all_values = []
        for ant in range(num_ants):
            solution = []
            total_weight = 0
            available = set(range(num_items))
            while available:
                prob = transition_matrix(pheromone[list(available)], cost[list(available)], alpha, beta)
                idx = np.random.choice(list(available), p=prob)
                if total_weight + weights[idx] <= capacity:
                    solution.append(idx)
                    total_weight += weights[idx]
                available.remove(idx)
            value = np.sum(values[solution])
            all_solutions.append(solution)
            all_values.append(value)
            if value > best_value:
                best_value = value
                best_solution = solution
        pheromone = pheromone_update(pheromone, all_solutions, all_values)
        convergence.append(best_value)
        pheromone_history.append(pheromone.copy())
    return best_solution, best_value, convergence, pheromone_history

# %%
def result_printing(scenario, best_solution, best_value):
    print(f"--- {scenario} ---")
    print("Best items:", [item_names[i] for i in best_solution])
    print("Best item weights:", weights[best_solution])
    print("Best item values:", values[best_solution])
    print("Total value:", best_value)
    print("Total weight:", np.sum(weights[best_solution]))

# %%
def plot_convergence(convergence1, convergence2):
    plt.figure()
    plt.plot(convergence1, label='Scenario 1')
    plt.plot(convergence2, label='Scenario 2')
    plt.xlabel('Iteration')
    plt.ylabel('Best Value')
    plt.title('ACO Convergence Comparison')
    plt.legend()
    plt.show()

# %%
def plot_pheromone(pheromone1, pheromone2):
    plt.figure()
    plt.bar(np.arange(num_items)-0.15, pheromone1, width=0.3, label='Scenario 1')
    plt.bar(np.arange(num_items)+0.15, pheromone2, width=0.3, label='Scenario 2')
    plt.xticks(np.arange(num_items), item_names, rotation=30)
    plt.xlabel('Item Name')
    plt.ylabel('Final Pheromone Level')
    plt.title('Final Pheromone Comparison')
    plt.legend()
    plt.show()

    plt.figure(figsize=(10, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(np.array(pheromone_history1), aspect='auto', cmap='viridis')
    plt.colorbar(label='Pheromone Level')
    plt.title('Scenario 1 Pheromone Map')
    plt.xlabel('Item Index')
    plt.ylabel('Iteration')
    plt.xticks(np.arange(num_items), item_names, rotation=30)

    plt.subplot(1, 2, 2)
    plt.imshow(np.array(pheromone_history2), aspect='auto', cmap='viridis')
    plt.colorbar(label='Pheromone Level')
    plt.title('Scenario 2 Pheromone Map')
    plt.xlabel('Item Index')
    plt.ylabel('Iteration')
    plt.xticks(np.arange(num_items), item_names, rotation=30)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### DYNAMIC INPUT

# %% [markdown]
# IMPORTANT : Dynamic Input must be got in this section. Display the possible states to choose from:
# This is applicable for all the relevent problems as mentioned in the question.

# %%
def get_items_input():
    print("Choose input method for items:")
    print("1. Use default items")
    print("2. Enter items manually")
    choice = input("Enter 1 or 2: ").strip()
    if choice == "1":
        return items
    elif choice == "2":
        try:
            n = int(input("How many items do you want to plan? "))
            manual_items = []
            for i in range(n):
                print(f"\nEnter details for item {i+1}:")
                name = input("  Name: ").strip()
                weight = float(input("  Weight (kg): "))
                value = float(input("  Value: "))
                manual_items.append({"name": name, "weight": weight, "value": value})
            return manual_items
        except Exception as e:
            print("Invalid input. Using default items.")
            return items
    else:
        print("Invalid choice. Using default items.")
        return items

selected_items = get_items_input()

if selected_items != items:
    items = selected_items
    weights = np.array([item["weight"] for item in items])
    values = np.array([item["value"] for item in items])
    item_names = [item["name"] for item in items]
    num_items = len(weights)
# Out:
# Choose input method for items:
# 1. Use default items
# 2. Enter items manually

# %% [markdown]
# ### 4.	Calling the search algorithms

# %%
#Invoke algorithm 1 (Should Print the solution, path, cost, Interpretation etc., (As mentioned in the problem))

# Run scenarios
best_solution1, best_value1, convergence1, pheromone_history1 = aco_algorithm(
    weights, values, capacity, num_ants=3, alpha=0.5, beta=3)
best_solution2, best_value2, convergence2, pheromone_history2 = aco_algorithm(
    weights, values, capacity, num_ants=5, alpha=0.5, beta=7)
# Out:
# Pheromone levels after update (per item):
#   Item Tent: 1.6200
#   Item Sleeping Bag: 1.6200
#   Item Water Bottle: 1.6200
#   Item Fruits: 1.6200
#   Item Mosquito bite cream: 0.9000
#   Item Map & Compass: 1.6200
#   Item Umberalla: 0.9000
#   Item Flashlight: 1.6200
#
# Pheromone levels after update (per item):
#   Item Tent: 2.1780
#   Item Sleeping Bag: 2.1780
#   Item Water Bottle: 2.1780
#   Item Fruits: 2.1780
#   Item Mosquito bite cream: 0.8100
#   Item Map & Compass: 2.1780
#   Item Umberalla: 0.8100
#   Item Flashlight: 2.1780
#
# Pheromone levels after update (per item):
#   Item Tent: 2.6802
#   Item Sleeping Bag: 2.6802
#   Item Water Bottle: 2.6802
#   Item Fruits: 2.6802
#   Item Mosquito bite cream: 0.7290
#   Item Map & Compass: 2.6802
#   Item Umberalla: 0.7290
#   Item Flashlight: 2.6802
#
# Pheromone levels after update (per item):
#   Item Tent: 3.1322
#   Item Sleeping Bag: 3.1322
#   Item Water Bottle: 3.1322
#   Item Fruits: 3.1322
#   Item Mosquito bite cream: 0.6561
#   Item Map & Compass: 3.1322
#   Item Umberalla: 0.6561
#   Item Flashlight: 3.1322
#
# Pheromone levels after update (per item):
#   Item Tent: 3.5390
#   Item Sleeping Bag: 3.5390
#   Item Water Bottle: 3.5390
#   Item Fruits: 3.5390
#   Item Mosquito bite cream: 0.5905
#   Item Map & Compass: 3.5390
#   Item Umberalla: 0.5905
#   Item Flashlight: 3.5390
#
# Pheromone levels after update (per item):
#   Item Tent: 3.9051
#   Item Sleeping Bag: 3.9051
#   Item Water Bottle: 3.9051
#   Item Fruits: 3.9051
#   Item Mosquito bite cream: 0.5314
#   Item Map & Compass: 3.9051
#   Item Umberalla: 0.5314
#   Item Flashlight: 3.9051
#
# Pheromone levels after update (per item):
#   Item Tent: 4.2346
#   Item Sleeping Bag: 4.2346
#   Item Water Bottle: 4.2346
#   Item Fruits: 4.2346
#   Item Mosquito bite cream: 0.4783
#   Item Map & Compass: 4.2346
#   Item Umberalla: 0.4783
#   Item Flashlight: 4.2346
#
# Pheromone levels after update (per item):
#   Item Tent: 4.5311
#   Item Sleeping Bag: 4.5311
#   Item Water Bottle: 4.5311
#   Item Fruits: 4.5311
#   Item Mosquito bite cream: 0.4305
#   Item Map & Compass: 4.5311
#   Item Umberalla: 0.4305
#   Item Flashlight: 4.5311
#
# Pheromone levels after update (per item):
#   Item Tent: 4.7980
#   Item Sleeping Bag: 4.7980
#   Item Water Bottle: 4.7980
#   Item Fruits: 4.7980
#   Item Mosquito bite cream: 0.3874
#   Item Map & Compass: 4.7980
#   Item Umberalla: 0.3874
#   Item Flashlight: 4.7980
#
# Pheromone levels after update (per item):
#   Item Tent: 5.0382
#   Item Sleeping Bag: 5.0382
#   Item Water Bottle: 5.0382
#   Item Fruits: 5.0382
#   Item Mosquito bite cream: 0.3487
#   Item Map & Compass: 5.0382
#   Item Umberalla: 0.3487
#   Item Flashlight: 5.0382
#
# Pheromone levels after update (per item):
#   Item Tent: 5.2544
#   Item Sleeping Bag: 5.2544
#   Item Water Bottle: 5.2544
#   Item Fruits: 5.2544
#   Item Mosquito bite cream: 0.3138
#   Item Map & Compass: 5.2544
#   Item Umberalla: 0.3138
#   Item Flashlight: 5.2544
#
# Pheromone levels after update (per item):
#   Item Tent: 5.4489
#   Item Sleeping Bag: 5.4489
#   Item Water Bottle: 5.4489
#   Item Fruits: 5.4489
#   Item Mosquito bite cream: 0.2824
#   Item Map & Compass: 5.4489
#   Item Umberalla: 0.2824
#   Item Flashlight: 5.4489
#
# Pheromone levels after update (per item):
#   Item Tent: 5.6240
#   Item Sleeping Bag: 5.6240
#   Item Water Bottle: 5.6240
#   Item Fruits: 5.6240
#   Item Mosquito bite cream: 0.2542
#   Item Map & Compass: 5.6240
#   Item Umberalla: 0.2542
#   Item Flashlight: 5.6240
#
# Pheromone levels after update (per item):
#   Item Tent: 5.7816
#   Item Sleeping Bag: 5.7816
#   Item Water Bottle: 5.7816
#   Item Fruits: 5.7816
#   Item Mosquito bite cream: 0.2288
#   Item Map & Compass: 5.7816
#   Item Umberalla: 0.2288
#   Item Flashlight: 5.7816
#
# Pheromone levels after update (per item):
#   Item Tent: 5.9235
#   Item Sleeping Bag: 5.9235
#   Item Water Bottle: 5.9235
#   Item Fruits: 5.9235
#   Item Mosquito bite cream: 0.2059
#   Item Map & Compass: 5.9235
#   Item Umberalla: 0.2059
#   Item Flashlight: 5.9235
#
# Pheromone levels after update (per item):
#   Item Tent: 6.0511
#   Item Sleeping Bag: 6.0511
#   Item Water Bottle: 6.0511
#   Item Fruits: 6.0511
#   Item Mosquito bite cream: 0.1853
#   Item Map & Compass: 6.0511
#   Item Umberalla: 0.1853
#   Item Flashlight: 6.0511
#
# Pheromone levels after update (per item):
#   Item Tent: 6.1660
#   Item Sleeping Bag: 6.1660
#   Item Water Bottle: 6.1660
#   Item Fruits: 6.1660
#   Item Mosquito bite cream: 0.1668
#   Item Map & Compass: 6.1660
#   Item Umberalla: 0.1668
#   Item Flashlight: 6.1660
#
# Pheromone levels after update (per item):
#   Item Tent: 6.2694
#   Item Sleeping Bag: 6.2694
#   Item Water Bottle: 6.2694
#   Item Fruits: 6.2694
#   Item Mosquito bite cream: 0.1501
#   Item Sleeping Bag: 2.1000
#   Item Water Bottle: 2.1000
#   Item Fruits: 2.1000
#   Item Mosquito bite cream: 0.9000
#   Item Map & Compass: 2.1000
#   Item Umberalla: 0.9000
#   Item Flashlight: 2.1000
#
# Pheromone levels after update (per item):
#   Item Tent: 3.0900
#   Item Sleeping Bag: 3.0900
#   Item Water Bottle: 3.0900
#   Item Fruits: 3.0900
#   Item Mosquito bite cream: 0.8100
#   Item Map & Compass: 3.0900
#   Item Umberalla: 0.8100
#   Item Flashlight: 3.0900
#
# Pheromone levels after update (per item):
#   Item Tent: 3.9810
#   Item Sleeping Bag: 3.9810
#   Item Water Bottle: 3.9810
#   Item Fruits: 3.9810
#   Item Mosquito bite cream: 0.7290
#   Item Map & Compass: 3.9810
#   Item Umberalla: 0.7290
#   Item Flashlight: 3.9810
#
# Pheromone levels after update (per item):
#   Item Tent: 4.7829
#   Item Sleeping Bag: 4.7829
#   Item Water Bottle: 4.7829
#   Item Fruits: 4.7829
#   Item Mosquito bite cream: 0.6561
#   Item Map & Compass: 4.7829
#   Item Umberalla: 0.6561
#   Item Flashlight: 4.7829
#
# Pheromone levels after update (per item):
#   Item Tent: 5.5046
#   Item Sleeping Bag: 5.5046
#   Item Water Bottle: 5.5046
#   Item Fruits: 5.5046
#   Item Mosquito bite cream: 0.5905
#   Item Map & Compass: 5.5046
#   Item Umberalla: 0.5905
#   Item Flashlight: 5.5046
#
# Pheromone levels after update (per item):
#   Item Tent: 6.1541
#   Item Sleeping Bag: 6.1541
#   Item Water Bottle: 6.1541
#   Item Fruits: 6.1541
#   Item Mosquito bite cream: 0.5314
#   Item Map & Compass: 6.1541
#   Item Umberalla: 0.5314
#   Item Flashlight: 6.1541
#
# Pheromone levels after update (per item):
#   Item Tent: 6.7387
#   Item Sleeping Bag: 6.7387
#   Item Water Bottle: 6.7387
#   Item Fruits: 6.7387
#   Item Mosquito bite cream: 0.4783
#   Item Map & Compass: 6.7387
#   Item Umberalla: 0.4783
#   Item Flashlight: 6.7387
#
# Pheromone levels after update (per item):
#   Item Tent: 7.2649
#   Item Sleeping Bag: 7.2649
#   Item Water Bottle: 7.2649
#   Item Fruits: 7.2649
#   Item Mosquito bite cream: 0.4305
#   Item Map & Compass: 7.2649
#   Item Umberalla: 0.4305
#   Item Flashlight: 7.2649
#
# Pheromone levels after update (per item):
#   Item Tent: 7.7384
#   Item Sleeping Bag: 7.7384
#   Item Water Bottle: 7.7384
#   Item Fruits: 7.7384
#   Item Mosquito bite cream: 0.3874
#   Item Map & Compass: 7.7384
#   Item Umberalla: 0.3874
#   Item Flashlight: 7.7384
#
# Pheromone levels after update (per item):
#   Item Tent: 8.1645
#   Item Sleeping Bag: 8.1645
#   Item Water Bottle: 8.1645
#   Item Fruits: 8.1645
#   Item Mosquito bite cream: 0.3487
#   Item Map & Compass: 8.1645
#   Item Umberalla: 0.3487
#   Item Flashlight: 8.1645
#
# Pheromone levels after update (per item):
#   Item Tent: 8.5481
#   Item Sleeping Bag: 8.5481
#   Item Water Bottle: 8.5481
#   Item Fruits: 8.5481
#   Item Mosquito bite cream: 0.3138
#   Item Map & Compass: 8.5481
#   Item Umberalla: 0.3138
#   Item Flashlight: 8.5481
#
# Pheromone levels after update (per item):
#   Item Tent: 8.8933
#   Item Sleeping Bag: 8.8933
#   Item Water Bottle: 8.8933
#   Item Fruits: 8.8933
#   Item Mosquito bite cream: 0.2824
#   Item Map & Compass: 8.8933
#   Item Umberalla: 0.2824
#   Item Flashlight: 8.8933
#
# Pheromone levels after update (per item):
#   Item Tent: 9.2039
#   Item Sleeping Bag: 9.2039
#   Item Water Bottle: 9.2039
#   Item Fruits: 9.2039
#   Item Mosquito bite cream: 0.2542
#   Item Map & Compass: 9.2039
#   Item Umberalla: 0.2542
#   Item Flashlight: 9.2039
#
# Pheromone levels after update (per item):
#   Item Tent: 9.4836
#   Item Sleeping Bag: 9.4836
#   Item Water Bottle: 9.4836
#   Item Fruits: 9.4836
#   Item Mosquito bite cream: 0.2288
#   Item Map & Compass: 9.4836
#   Item Umberalla: 0.2288
#   Item Flashlight: 9.4836
#
# Pheromone levels after update (per item):
#   Item Tent: 9.7352
#   Item Sleeping Bag: 9.7352
#   Item Water Bottle: 9.7352
#   Item Fruits: 9.7352
#   Item Mosquito bite cream: 0.2059
#   Item Map & Compass: 9.7352
#   Item Umberalla: 0.2059
#   Item Flashlight: 9.7352
#
# Pheromone levels after update (per item):
#   Item Tent: 9.9617
#   Item Sleeping Bag: 9.9617
#   Item Water Bottle: 9.9617
#   Item Fruits: 9.9617
#   Item Mosquito bite cream: 0.1853
#   Item Map & Compass: 9.9617
#   Item Umberalla: 0.1853
#   Item Flashlight: 9.9617
#
# Pheromone levels after update (per item):
#   Item Tent: 10.1655
#   Item Sleeping Bag: 10.1655
#   Item Water Bottle: 10.1655
#   Item Fruits: 10.1655
#   Item Mosquito bite cream: 0.1668
#   Item Map & Compass: 10.1655
#   Item Umberalla: 0.1668
#   Item Flashlight: 10.1655
#
# Pheromone levels after update (per item):
#   Item Tent: 10.3490
#   Item Sleeping Bag: 10.3490
#   Item Water Bottle: 10.3490
#   Item Fruits: 10.3490
#   Item Mosquito bite cream: 0.1501
#   Item Map & Compass: 10.3490
#   Item Umberalla: 0.1501
#   Item Flashlight: 10.3490
#
# Pheromone levels after update (per item):
#   Item Tent: 10.5141
#   Item Sleeping Bag: 10.5141
#   Item Water Bottle: 10.5141
#   Item Fruits: 10.5141
#   Item Mosquito bite cream: 0.1351
#   Item Map & Compass: 10.5141
#   Item Umberalla: 0.1351
#   Item Flashlight: 10.5141
#
# Pheromone levels after update (per item):
#   Item Tent: 10.6627
#   Item Sleeping Bag: 10.6627
#   Item Water Bottle: 10.6627
#   Item Fruits: 10.6627
#   Item Mosquito bite cream: 0.1216
#   Item Map & Compass: 10.6627
#   Item Umberalla: 0.1216
#   Item Flashlight: 10.6627
#
# Pheromone levels after update (per item):
#   Item Tent: 10.7964
#   Item Sleeping Bag: 10.7964
#   Item Water Bottle: 10.7964
#   Item Fruits: 10.7964
#   Item Mosquito bite cream: 0.1094
#   Item Map & Compass: 10.7964
#   Item Umberalla: 0.1094
#   Item Flashlight: 10.7964
#
# Pheromone levels after update (per item):
#   Item Tent: 10.9168
#   Item Sleeping Bag: 10.9168
#   Item Water Bottle: 10.9168
#   Item Fruits: 10.9168
#   Item Mosquito bite cream: 0.0985
#   Item Map & Compass: 10.9168
#   Item Umberalla: 0.0985
#   Item Flashlight: 10.9168
#
# Pheromone levels after update (per item):
#   Item Tent: 11.0251
#   Item Sleeping Bag: 11.0251
#   Item Water Bottle: 11.0251
#   Item Fruits: 11.0251
#   Item Mosquito bite cream: 0.0886
#   Item Map & Compass: 11.0251
#   Item Umberalla: 0.0886
#   Item Flashlight: 11.0251
#
# Pheromone levels after update (per item):
#   Item Tent: 11.1226
#   Item Sleeping Bag: 11.1226
#   Item Water Bottle: 11.1226
#   Item Fruits: 11.1226
#   Item Mosquito bite cream: 0.0798
#   Item Map & Compass: 11.1226
#   Item Umberalla: 0.0798
#   Item Flashlight: 11.1226
#
# Pheromone levels after update (per item):
#   Item Tent: 11.2103
#   Item Sleeping Bag: 11.2103
#   Item Water Bottle: 11.2103
#   Item Fruits: 11.2103
#   Item Mosquito bite cream: 0.0718
#   Item Map & Compass: 11.2103
#   Item Umberalla: 0.0718
#   Item Flashlight: 11.2103
#
# Pheromone levels after update (per item):
#   Item Tent: 11.2893
#   Item Sleeping Bag: 11.2893
#   Item Water Bottle: 11.2893
#   Item Fruits: 11.2893
#   Item Mosquito bite cream: 0.0646
#   Item Map & Compass: 11.2893
#   Item Umberalla: 0.0646
#   Item Flashlight: 11.2893
#
# Pheromone levels after update (per item):
#   Item Tent: 11.3604
#   Item Sleeping Bag: 11.3604
#   Item Water Bottle: 11.3604
#   Item Fruits: 11.3604
#   Item Mosquito bite cream: 0.0581
#   Item Map & Compass: 11.3604
#   Item Umberalla: 0.0581
#   Item Flashlight: 11.3604
#
# Pheromone levels after update (per item):
#   Item Tent: 11.4243
#   Item Sleeping Bag: 11.4243
#   Item Water Bottle: 11.4243
#   Item Fruits: 11.4243
#   Item Mosquito bite cream: 0.0523
#   Item Map & Compass: 11.4243
#   Item Umberalla: 0.0523
#   Item Flashlight: 11.4243
#
# Pheromone levels after update (per item):
#   Item Tent: 11.4819
#   Item Sleeping Bag: 11.4819
#   Item Water Bottle: 11.4819
#   Item Fruits: 11.4819
#   Item Mosquito bite cream: 0.0471
#   Item Map & Compass: 11.4819
#   Item Umberalla: 0.0471
#   Item Flashlight: 11.4819
#
# Pheromone levels after update (per item):
#   Item Tent: 11.5337
#   Item Sleeping Bag: 11.5337
#   Item Water Bottle: 11.5337
#   Item Fruits: 11.5337
#   Item Mosquito bite cream: 0.0424
#   Item Map & Compass: 11.5337
#   Item Umberalla: 0.0424
#   Item Flashlight: 11.5337
#
# Pheromone levels after update (per item):
#   Item Tent: 11.5803
#   Item Sleeping Bag: 11.5803
#   Item Water Bottle: 11.5803
#   Item Fruits: 11.5803
#   Item Mosquito bite cream: 0.0382
#   Item Map & Compass: 11.5803
#   Item Umberalla: 0.0382
#   Item Flashlight: 11.5803
#
# Pheromone levels after update (per item):
#   Item Tent: 11.6223
#   Item Sleeping Bag: 11.6223
#   Item Water Bottle: 11.6223
#   Item Fruits: 11.6223
#   Item Mosquito bite cream: 0.0343
#   Item Map & Compass: 11.6223
#   Item Umberalla: 0.0343
#   Item Flashlight: 11.6223
#
# Pheromone levels after update (per item):
#   Item Tent: 11.6601
#   Item Sleeping Bag: 11.6601
#   Item Water Bottle: 11.6601
#   Item Fruits: 11.6601
#   Item Mosquito bite cream: 0.0309
#   Item Map & Compass: 11.6601
#   Item Umberalla: 0.0309
#   Item Flashlight: 11.6601
#
# Pheromone levels after update (per item):
#   Item Tent: 11.6941
#   Item Sleeping Bag: 11.6941
#   Item Water Bottle: 11.6941
#   Item Fruits: 11.6941
#   Item Mosquito bite cream: 0.0278
#   Item Map & Compass: 11.6941
#   Item Umberalla: 0.0278
#   Item Flashlight: 11.6941
#
# Pheromone levels after update (per item):
#   Item Tent: 11.7247
#   Item Sleeping Bag: 11.7247
#   Item Water Bottle: 11.7247
#   Item Fruits: 11.7247
#   Item Mosquito bite cream: 0.0250
#   Item Map & Compass: 11.7247
#   Item Umberalla: 0.0250
#   Item Flashlight: 11.7247
#
# Pheromone levels after update (per item):
#   Item Tent: 11.7522
#   Item Sleeping Bag: 11.7522
#   Item Water Bottle: 11.7522
#   Item Fruits: 11.7522
#   Item Mosquito bite cream: 0.0225
#   Item Map & Compass: 11.7522
#   Item Umberalla: 0.0225
#   Item Flashlight: 11.7522
#
# Pheromone levels after update (per item):
#   Item Tent: 11.7770
#   Item Sleeping Bag: 11.7770
#   Item Water Bottle: 11.7770
#   Item Fruits: 11.7770
#   Item Mosquito bite cream: 0.0203
#   Item Map & Compass: 11.7770
#   Item Umberalla: 0.0203
#   Item Flashlight: 11.7770
#
# Pheromone levels after update (per item):
#   Item Tent: 11.7993
#   Item Sleeping Bag: 11.7993
#   Item Water Bottle: 11.7993
#   Item Fruits: 11.7993
#   Item Mosquito bite cream: 0.0182
#   Item Map & Compass: 11.7993
#   Item Umberalla: 0.0182
#   Item Flashlight: 11.7993
#
# Pheromone levels after update (per item):
#   Item Tent: 11.8193
#   Item Sleeping Bag: 11.8193
#   Item Water Bottle: 11.8193
#   Item Fruits: 11.8193
#   Item Mosquito bite cream: 0.0164
#   Item Map & Compass: 11.8193
#   Item Umberalla: 0.0164
#   Item Flashlight: 11.8193
#
# Pheromone levels after update (per item):
#   Item Tent: 11.8374
#   Item Sleeping Bag: 11.8374
#   Item Water Bottle: 11.8374
#   Item Fruits: 11.8374
#   Item Mosquito bite cream: 0.0148
#   Item Map & Compass: 11.8374
#   Item Umberalla: 0.0148
#   Item Flashlight: 11.8374
#
# Pheromone levels after update (per item):
#   Item Tent: 11.8537
#   Item Sleeping Bag: 11.8537
#   Item Water Bottle: 11.8537
#   Item Fruits: 11.8537
#   Item Mosquito bite cream: 0.0133
#   Item Map & Compass: 11.8537
#   Item Umberalla: 0.0133
#   Item Flashlight: 11.8537
#
# Pheromone levels after update (per item):
#   Item Tent: 11.8683
#   Item Sleeping Bag: 11.8683
#   Item Water Bottle: 11.8683
#   Item Fruits: 11.8683
#   Item Mosquito bite cream: 0.0120
#   Item Map & Compass: 11.8683
#   Item Umberalla: 0.0120
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9994
#   Item Sleeping Bag: 11.9994
#   Item Water Bottle: 11.9994
#   Item Fruits: 11.9994
#   Item Mosquito bite cream: 0.0001
#   Item Map & Compass: 11.9994
#   Item Umberalla: 0.0001
#   Item Flashlight: 11.9994
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9995
#   Item Sleeping Bag: 11.9995
#   Item Water Bottle: 11.9995
#   Item Fruits: 11.9995
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9995
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9995
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9995
#   Item Sleeping Bag: 11.9995
#   Item Water Bottle: 11.9995
#   Item Fruits: 11.9995
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9995
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9995
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9996
#   Item Sleeping Bag: 11.9996
#   Item Water Bottle: 11.9996
#   Item Fruits: 11.9996
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9996
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9996
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9996
#   Item Sleeping Bag: 11.9996
#   Item Water Bottle: 11.9996
#   Item Fruits: 11.9996
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9996
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9996
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9996
#   Item Sleeping Bag: 11.9996
#   Item Water Bottle: 11.9996
#   Item Fruits: 11.9996
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9996
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9996
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9997
#   Item Sleeping Bag: 11.9997
#   Item Water Bottle: 11.9997
#   Item Fruits: 11.9997
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9997
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9997
#
# Pheromone levels after update (per item):
#   Item Tent: 11.9997
#   Item Sleeping Bag: 11.9997
#   Item Water Bottle: 11.9997
#   Item Fruits: 11.9997
#   Item Mosquito bite cream: 0.0000
#   Item Map & Compass: 11.9997
#   Item Umberalla: 0.0000
#   Item Flashlight: 11.9997

# %%
result_printing("\nScenario 1", best_solution1, best_value1)
result_printing("\nScenario 2", best_solution2, best_value2)
print("\nTransition matrix (Scenario 1, initial):")
print(transition_matrix(np.ones(num_items), cost_matrix(weights, values), alpha=0.5, beta=3))

print("\nPheromone matrix (Scenario 1, final):")
print(pheromone_history1[-1])

print("\nTransition matrix (Scenario 2, initial):")
print(transition_matrix(np.ones(num_items), cost_matrix(weights, values), alpha=0.5, beta=7))

print("\nPheromone matrix (Scenario 2, final):")
print(pheromone_history2[-1])

plot_convergence(convergence1, convergence2)
plot_pheromone(pheromone_history1[-1], pheromone_history2[-1])
# Out:
# ---
# Scenario 1 ---
# Best items: ['Sleeping Bag', 'Flashlight', 'Water Bottle', 'Fruits', 'Tent', 'Map & Compass']
# Best item weights: [3 1 4 2 5 5]
# Best item values: [3 7 1 6 2 5]
# Total value: 24
# Total weight: 20
# ---
# Scenario 2 ---
# Best items: ['Water Bottle', 'Flashlight', 'Sleeping Bag', 'Fruits', 'Tent', 'Map & Compass']
# Best item weights: [4 1 3 2 5 5]
# Best item values: [1 7 3 6 2 5]
# Total value: 24
# Total weight: 20
#
# Transition matrix (Scenario 1, initial):
# [8.92049361e-02 2.60072700e-01 2.60072700e-01 1.09718170e-01
#  4.06363594e-03 1.66446528e-02 1.50505035e-04 2.60072700e-01]
#
# Pheromone matrix (Scenario 1, final):
# [7.19969323e+00 7.19974987e+00 7.19962095e+00 7.19974987e+00
#  2.12128604e-04 7.19956431e+00 2.65613989e-05 7.19962095e+00]
#
# Transition matrix (Scenario 2, initial):
# [2.55954425e-02 3.10796674e-01 3.10796674e-01 4.14863480e-02
#  1.89695236e-05 5.09209271e-04 8.67376477e-09 3.10796674e-01]
#
# Pheromone matrix (Scenario 2, final):
# [1.19997078e+01 1.19997078e+01 1.19997078e+01 1.19997078e+01
#  2.65613989e-05 1.19997078e+01 2.65613989e-05 1.19997078e+01]

# %% [markdown]
# ### 5.	Comparitive Analysis

# %%
#Code Block : Print the Time & Space complexity of algorithm

# Use solution and value from selected scenario (Scenario 1)
solution = best_solution1
value = best_value1
# Also get solution and value for Scenario 2
solution2 = best_solution2
value2 = best_value2

# Parameters used in the ACO runs (from cell 22)
num_ants1 = 3
num_iterations1 = 100
num_items1 = num_items

num_ants2 = 5
num_iterations2 = 100
num_items2 = num_items

# Measure execution time for a single run of the algorithm (simulate with a dummy operation)
start_time = time.time()
_ = sum(solution)  # Dummy operation to simulate usage
end_time = time.time()

# Estimate memory usage of main variables (rough estimate)
memory_usage = (
    sys.getsizeof(solution) +
    sys.getsizeof(value) +
    sys.getsizeof(weights) +
    sys.getsizeof(values)
)

print("=== Scenario 1 ===")
print(f"Execution time (Scenario 1): {end_time - start_time:.6f} seconds")
print(f"Approximate memory usage (Scenario 1): {memory_usage} bytes")
print(f"Time Complexity (Scenario 1): O(num_iterations * num_ants * num_items^2) = {num_iterations1 * num_ants1 * num_items1 ** 2}")
print(f"Space Complexity (Scenario 1): O(num_items + num_ants * num_items) = {num_items1 + num_ants1 * num_items1}")

# Repeat for Scenario 2
start_time2 = time.time()
_ = sum(solution2)
end_time2 = time.time()

memory_usage2 = (
    sys.getsizeof(solution2) +
    sys.getsizeof(value2) +
    sys.getsizeof(weights) +
    sys.getsizeof(values)
)

print("\n=== Scenario 2 ===")
print(f"Execution time (Scenario 2): {end_time2 - start_time2:.6f} seconds")
print(f"Approximate memory usage (Scenario 2): {memory_usage2} bytes")
print(f"Time Complexity (Scenario 2): O(num_iterations * num_ants * num_items^2) = {num_iterations2 * num_ants2 * num_items2 ** 2}")
print(f"Space Complexity (Scenario 2): O(num_items + num_ants * num_items) = {num_items2 + num_ants2 * num_items2}")
# Out:
# === Scenario 1 ===
# Execution time (Scenario 1): 0.000181 seconds
# Approximate memory usage (Scenario 1): 504 bytes
# Time Complexity (Scenario 1): O(num_iterations * num_ants * num_items^2) = 19200
# Space Complexity (Scenario 1): O(num_items + num_ants * num_items) = 32
#
# === Scenario 2 ===
# Execution time (Scenario 2): 0.000046 seconds
# Approximate memory usage (Scenario 2): 504 bytes
# Time Complexity (Scenario 2): O(num_iterations * num_ants * num_items^2) = 32000
# Space Complexity (Scenario 2): O(num_items + num_ants * num_items) = 48
